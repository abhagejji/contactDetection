# %%
# # Install PyTorch Lightning (if not already installed)
# !pip install pytorch-lightning
# !pip install torchmetrics
# !pip install h5py
# !pip install tensorboard

# %%
# from google.colab import drive
# drive.mount("/content/drive")

# %%
# Import necessary libraries
import torch
import pytorch_lightning as pl
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader,Dataset
from torchmetrics import Accuracy
import torch.nn as nn
import torch.nn.functional as F
import h5py
import pandas as pd
import numpy as np
import os
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping

# %%
# !ls drive/MyDrive/Dans_lab/Data/secondUnzip/images_rendered_try2/
# !ls /panfs/jay/groups/27/kersten/gejji003/Shadows/trained_models/round1
# Out:
# checkpoint  logger

# %%
# os.path.exists("drive/MyDrive/Dans_lab/Data/trained_models/round1")

# %%
# print(torch.cuda.is_available())

# %%
# specifing all valiables in a single place

logger_dir = "/panfs/jay/groups/27/kersten/gejji003/Shadows/trained_models/round1/logger/"
checkpt_dirpath = "/panfs/jay/groups/27/kersten/gejji003/Shadows/trained_models/round1/checkpoint/"
class MyDataManager():
    def __init__(self):

        self.column_x = 'path_to_img'
        self.column_y =  'label'

        self.base_path = "/panfs/jay/groups/27/kersten/gejji003/Shadows/data/images_rendered_try2/"
        self.file_path_train = self.base_path +"trainData.csv"
        self.file_path_val = self.base_path +"valData.csv"
        self.file_path_test = self.base_path +"testData.csv"

        self.column_x = 'path_to_img'
        self.column_y = 'label'

        self.color_channel = "colors"
        self.shadow_channel = "cast_shadow"

        self.default_string = self.base_path

        if not os.path.exists(self.file_path_train):
            raise Exception("The training csv does not exists")


        self.train_df = pd.read_csv(self.file_path_train)
        self.val_df = pd.read_csv(self.file_path_val)
        self.test_df = pd.read_csv(self.file_path_test)

    def split_xy(self,df):
        colx = df[self.column_x]
        x = colx.apply(lambda x: self.default_string + x if isinstance(x, str) else x)

        #print("----------------- to note_________",x[9])
        return x,df[self.column_y]

class MyTansforms():
    def __init__(self):
        pass

    def shadow_training_transform(self):
        self.traintransforms = transforms.Compose([
            transforms.GaussianBlur(kernel_size = 5),
            transforms.RandomResizedCrop(244),
            transforms.RandomHorizontalFlip(),
            transforms.ColorJitter(brightness = 0.2, contrast = 0.2),
            transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5)),
        ])
        return self.traintransforms
    def shadow_test_transform(self,):
        self.testtransforms = transforms.Compose([
            transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5)),
        ])
        return self.testtransforms

# %%
class MyDataLoading(Dataset):
    # for fine grain control over hoe each img is preproceed
    def __init__(self, x,y,color_channel,shadow_channel,mode,batch_size = 16, transforms=None):
        self.data_paths = x
        self.label = y
        self.transform = transforms
        self.mode = mode
        self.transforms = transforms
        self.batch_size = 16
        self.color = color_channel
        self.shadow =shadow_channel

    def __len__(self):
        return len(self.data_paths)

    def __getitem__(self, idx):
        # Load and preprocess individual
        image_path = self.data_paths[idx]
        if self.mode =="train":
            try:
                with h5py.File(image_path,"r") as f:
                    colorTensor = torch.tensor(np.array(f[self.color]), dtype= torch.float32)
                    colorTensor = torch.permute(colorTensor, [2,0,1])
#                     shadowTensor = torch.tensor(np.array(f[self.shadow]), dtype= torch.float32).unsqueeze(-1)
#                     shadowTensor = torch.permute(shadowTensor, [2,0,1])
#                 x = torch.cat((colorTensor,shadowTensor), dim = 0)#TODO colorTensor #
                x = colorTensor
                y = torch.tensor(self.label[idx], dtype = torch.long)
            except:
                print("error in reading train file : ",image_path, self.color, self.shadow)
                x = torch.tensor(np.zeros([4,512,512]), dtype = torch.float32)
                y = torch.tensor(np.random.randint(0,2), dtype = torch.long)

        # elif self.mode =="test":
        #     try:
        #         with h5py.File(image_path,"r") as f:
        #             colorTensor = torch.tensor(f[self.color], dtype= torch.float32)
        #             colorTensor = torch.permute(colorTensor, [2,0,1])
        #             shadowTensor = torch.tensor(f[self.shadow], dtype= torch.float32).unsqueeze(-1)
        #             shadowTensor = torch.permute(shadowTensor, [2,0,1])
        #         x = torch.cat((colorTensor,shadowTensor), dim = 0) #colorTensor #
        #         y = torch.tensor(self.label[idx], dtype = torch.long) #TODO
        #     except:
        #         print("error in reading test file : ",image_path)
        #         x = torch.tensor(np.zeros([4,512,512]), dtype = torch.float32)
        #         y = torch.tensor(np.random.randint(0,2), dtype = torch.long)

        return x, y

# %%
class MyDataset(pl.LightningModule):

    def __init__(self):
        super().__init__()

        self.data_manager = MyDataManager()
        self.color_channel = self.data_manager.color_channel
        self.shadow_channel = self.data_manager.shadow_channel
        self.num_workers = 16 #TODO
        self.batch_size = 64

        self.transforms = MyTansforms()
        self.transforms_train = self.transforms.shadow_training_transform()

    def train_dataloader(self):
        return DataLoader(self.train_data, batch_size= self.batch_size, shuffle=True, num_workers=self.num_workers)#self.data_manager.get_train_dataloader()
        #,last_drop = True, prefetch_factor = 2
    def val_dataloader(self):
        return DataLoader(self.val_data, batch_size= self.batch_size, shuffle=False, num_workers=self.num_workers)#self.data_manager.get_train_dataloader() #self.data_manager.get_validation_dataloader()

    def test_dataloader(self):
        return DataLoader(self.test_data, batch_size= self.batch_size, shuffle=False, num_workers=self.num_workers)

    def setup(self, stage: str) ->None:
        self.trainX, self.trainY = self.data_manager.split_xy(self.data_manager.train_df)
        self.train_data = MyDataLoading(self.trainX, self.trainY, color_channel = self.color_channel, shadow_channel =self.shadow_channel,mode = "train" , transforms =  self.transforms_train )

        self.valX, self.valY = self.data_manager.split_xy(self.data_manager.val_df)
        self.val_data = MyDataLoading(self.valX, self.valY, color_channel = self.color_channel, shadow_channel =self.shadow_channel,mode = "train" , transforms =  self.transforms_train )

        self.testX, self.testY = self.data_manager.split_xy(self.data_manager.test_df)
        self.test_data = MyDataLoading(self.testX, self.testY, color_channel = self.color_channel, shadow_channel =self.shadow_channel,mode = "train" , transforms =  self.transforms_train )

# %%
# Define a LightningModule
class MYEfficientNetModel(pl.LightningModule):
    def __init__(self, num_classes, input_channels=3):
        super().__init__() # call the constructor of parents class
        self.save_hyperparameters()
        self.num_classes = num_classes
        self.model = models.efficientnet_b0(pretrained=True)
        self.model.features[0][0] = nn.Conv2d(input_channels, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
        # in_features = self.model.classifier.in_features
        self.model.classifier = nn.Linear(1280, self.num_classes)
        #self.train_acc = Accuracy()  # Create an instance of Accuracy metric for training

    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        logits = self(x)
        loss = torch.nn.functional.cross_entropy(logits, y)
        self.log('train_loss', loss, on_step=True, on_epoch=True, prog_bar=True)

        # predicted_probs = torch.sigmoid(logits)
        # predicted_labels = (predicted_probs >= 0.5).float()  # Threshold at 0.5 for binary classification
        # accuracy = (predicted_labels.squeeze() == y).float().mean()  # Make sure to squeeze the predictions if needed

        # self.log('train_acc', accuracy)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        logits = self(x)
        loss = torch.nn.functional.cross_entropy(logits, y)
        self.log('val_loss', loss, on_step=False, on_epoch=True, prog_bar=True)

        # predicted_probs = torch.sigmoid(logits)
        # predicted_labels = (predicted_probs >= 0.5).float()  # Threshold at 0.5 for binary classification
        # accuracy = (predicted_labels.squeeze() == y).float().mean()  # Make sure to squeeze the predictions if needed

        # self.log('train_acc', accuracy)

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=1e-3)

# %%
# myModel = models.efficientnet_b0(pretrained=True)
# print(myModel.features[0][0])

# %%
# !ls /content/drive/MyDrive/Dans_lab/Data/tempData/images_rendered_try2

# %%
dataset = MyDataset()

# %%
model = MYEfficientNetModel(num_classes = 2, input_channels=3)
# Out:
# /home/kersten/gejji003/.conda/envs/pytorchEnv/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/kersten/gejji003/.conda/envs/pytorchEnv/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
logger = TensorBoardLogger(save_dir=logger_dir, name="my_experiment")

# %%
early_stopping_callback = EarlyStopping(
    monitor='val_loss',  # The metric to monitor for early stopping (e.g., validation loss)
    patience=20,           # Number of epochs with no improvement after which training will be stopped
    mode='min',            # 'min' means we want to minimize the monitored metric, 'max' means maximize
)
model_checkpoint_callback = ModelCheckpoint(
                                    dirpath=checkpt_dirpath,  # Directory to save checkpoints
                                    filename='model-{epoch:02d}-{val_loss:.2f}',  # File name format
                                    save_top_k=3,  # Save the top 3 best models
                                    monitor='val_loss',  # Monitor validation loss
                                    mode='min',  # Choose 'min' or 'max' depending on the monitored metric
                                    )
# Create a Lightning Trainer
trainer = pl.Trainer(max_epochs=100, accelerator = "gpu",logger=logger, log_every_n_steps=1,
                     callbacks=[model_checkpoint_callback, early_stopping_callback]
        )
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
# Create the model and train
# model = EfficientNetModel(num_classes=len(dataset.classes))
trainer.fit(model, datamodule = dataset)
# Out:
# /home/kersten/gejji003/.conda/envs/pytorchEnv/lib/python3.11/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:617: UserWarning: Checkpoint directory /panfs/jay/groups/27/kersten/gejji003/Shadows/trained_models/round1/checkpoint exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type         | Params
# ---------------------------------------
# 0 | model | EfficientNet | 4.0 M
# ---------------------------------------
# 4.0 M     Trainable params
# 0         Non-trainable params
# 4.0 M     Total params
# 16.040    Total estimated model params size (MB)
# SLURM auto-requeueing enabled. Setting signal handlers.
# Epoch 0: 100%|██████████| 62/62 [00:25<00:00,  2.43it/s, v_num=6, train_loss_step=0.718]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 79.31it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:00, 14.91it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.82it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.63it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.96it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.60it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.36it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.20it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:00<00:00,  9.11it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  9.05it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.99it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.96it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.91it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.88it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.85it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.95it/s]
# Epoch 1: 100%|██████████| 62/62 [00:26<00:00,  2.30it/s, v_num=6, train_loss_step=0.567, val_loss=0.682, train_loss_epoch=0.703]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 79.61it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:00, 14.53it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.23it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.47it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.97it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.57it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.32it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.13it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:00<00:00,  9.01it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  8.98it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.95it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.91it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.89it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.86it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.84it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.98it/s]
# Epoch 2: 100%|██████████| 62/62 [00:25<00:00,  2.40it/s, v_num=6, train_loss_step=0.228, val_loss=0.637, train_loss_epoch=0.601]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 82.36it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:00, 14.93it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.82it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.75it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01, 10.21it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.94it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.75it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.63it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:00<00:00,  9.53it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  9.36it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  9.28it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  9.19it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  9.12it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  9.06it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  9.02it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  9.15it/s]
# Epoch 3: 100%|██████████| 62/62 [00:25<00:00,  2.44it/s, v_num=6, train_loss_step=0.232, val_loss=0.641, train_loss_epoch=0.431]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 82.37it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:00, 14.89it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.63it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.52it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.90it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.54it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.30it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.17it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:00<00:00,  9.04it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  9.01it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.94it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.91it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.85it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.86it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.84it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.99it/s]
# Epoch 4: 100%|██████████| 62/62 [00:25<00:00,  2.45it/s, v_num=6, train_loss_step=0.255, val_loss=0.493, train_loss_epoch=0.325]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 84.28it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:00, 15.00it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.70it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.83it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01, 10.34it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:00, 10.04it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.81it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.61it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:00<00:00,  9.47it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  9.36it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  9.29it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  9.22it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  9.11it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  9.02it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.95it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  9.08it/s]
# Epoch 5: 100%|██████████| 62/62 [00:25<00:00,  2.44it/s, v_num=6, train_loss_step=0.370, val_loss=0.385, train_loss_epoch=0.267]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 76.94it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:00, 14.93it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.79it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.75it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01, 10.19it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.88it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.57it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.39it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:00<00:00,  9.26it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  9.17it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  9.13it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  9.08it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  9.06it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  9.01it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.99it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  9.12it/s]
# Epoch 6: 100%|██████████| 62/62 [00:25<00:00,  2.42it/s, v_num=6, train_loss_step=0.127, val_loss=0.491, train_loss_epoch=0.220]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 80.77it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:00, 14.46it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.52it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.60it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.94it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.60it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.35it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.24it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:00<00:00,  9.14it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  9.10it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  9.07it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  9.03it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.98it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.96it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.90it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  9.01it/s]
# Epoch 7: 100%|██████████| 62/62 [00:25<00:00,  2.42it/s, v_num=6, train_loss_step=0.0814, val_loss=0.760, train_loss_epoch=0.162]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 83.43it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:00, 14.24it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.38it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.42it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.92it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.69it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.49it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.33it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:00<00:00,  9.21it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  9.10it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  9.03it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.97it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.92it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.90it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.86it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  9.00it/s]
# Epoch 8: 100%|██████████| 62/62 [00:25<00:00,  2.42it/s, v_num=6, train_loss_step=0.164, val_loss=0.531, train_loss_epoch=0.149]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 77.22it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:03,  4.20it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:02,  5.00it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:02,  5.55it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  5.94it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  6.21it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:01<00:01,  6.42it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:01<00:01,  6.61it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:01<00:01,  6.76it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  6.89it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  7.00it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  7.10it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  7.17it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  7.24it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:02<00:00,  7.32it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:02<00:00,  7.49it/s]
# Epoch 9: 100%|██████████| 62/62 [00:25<00:00,  2.39it/s, v_num=6, train_loss_step=0.0533, val_loss=0.374, train_loss_epoch=0.122]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 84.41it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:00, 15.30it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.81it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.78it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01, 10.26it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.79it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.51it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.33it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:00<00:00,  9.22it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  9.09it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  9.01it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.96it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.88it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.86it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.83it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.97it/s]
# Epoch 10: 100%|██████████| 62/62 [00:25<00:00,  2.43it/s, v_num=6, train_loss_step=0.0575, val_loss=0.352, train_loss_epoch=0.113]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 62.98it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:01, 13.22it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 10.69it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01,  9.83it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.44it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.17it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.02it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  8.90it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:01<00:00,  8.84it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  8.78it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.73it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.70it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.67it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.64it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.61it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.75it/s]
# Epoch 11: 100%|██████████| 62/62 [00:25<00:00,  2.41it/s, v_num=6, train_loss_step=0.0864, val_loss=0.456, train_loss_epoch=0.0993]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 83.31it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:00, 14.90it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.75it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.64it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01, 10.10it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.79it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.55it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.38it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:00<00:00,  9.25it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  9.19it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  9.15it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  9.11it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  9.06it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.96it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.89it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  9.02it/s]
# Epoch 12: 100%|██████████| 62/62 [00:25<00:00,  2.40it/s, v_num=6, train_loss_step=0.0145, val_loss=0.424, train_loss_epoch=0.0667]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 70.71it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:01, 13.93it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.02it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.03it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.59it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.36it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.23it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.13it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:00<00:00,  9.04it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  8.92it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.83it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.77it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.74it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.68it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.59it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.72it/s]
# Epoch 13: 100%|██████████| 62/62 [00:26<00:00,  2.35it/s, v_num=6, train_loss_step=0.154, val_loss=0.459, train_loss_epoch=0.0574]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 76.40it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:01, 13.91it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.14it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.09it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.63it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.32it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.13it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.00it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:01<00:00,  8.87it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  8.78it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.71it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.67it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.60it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.55it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.52it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.65it/s]
# Epoch 14: 100%|██████████| 62/62 [00:26<00:00,  2.36it/s, v_num=6, train_loss_step=0.0109, val_loss=0.459, train_loss_epoch=0.0505]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 73.48it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:01, 13.71it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 10.99it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01,  9.88it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.44it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.14it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.00it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  8.97it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:01<00:00,  8.90it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  8.85it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.78it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.74it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.73it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.71it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.67it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.80it/s]
# Epoch 15: 100%|██████████| 62/62 [00:25<00:00,  2.40it/s, v_num=6, train_loss_step=0.131, val_loss=0.423, train_loss_epoch=0.0631]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 70.30it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:01, 13.76it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 10.98it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.13it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.63it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.28it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.08it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  8.94it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:01<00:00,  8.82it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  8.73it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.65it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.60it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.54it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.50it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.48it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.64it/s]
# Epoch 16: 100%|██████████| 62/62 [00:25<00:00,  2.41it/s, v_num=6, train_loss_step=0.0589, val_loss=0.446, train_loss_epoch=0.0507]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 74.64it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:00, 14.61it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.00it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.10it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.68it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.45it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.24it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.11it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:00<00:00,  9.02it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  8.94it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.88it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.86it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.79it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.77it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.76it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.90it/s]
# Epoch 17: 100%|██████████| 62/62 [00:25<00:00,  2.40it/s, v_num=6, train_loss_step=0.0167, val_loss=0.437, train_loss_epoch=0.0457]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 76.02it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:01, 13.95it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 10.98it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.06it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.56it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.27it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.05it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  8.97it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:01<00:00,  8.91it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  8.81it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.70it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.67it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.68it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.66it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.63it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.77it/s]
# Epoch 18: 100%|██████████| 62/62 [00:26<00:00,  2.36it/s, v_num=6, train_loss_step=0.00307, val_loss=0.531, train_loss_epoch=0.0452]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 69.23it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:01, 13.31it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 10.71it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01,  9.97it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.67it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.46it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.30it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.18it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:00<00:00,  9.10it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  9.03it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.97it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.95it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.92it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.89it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.82it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.97it/s]
# Epoch 19: 100%|██████████| 62/62 [00:25<00:00,  2.39it/s, v_num=6, train_loss_step=0.00528, val_loss=0.417, train_loss_epoch=0.042]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 81.05it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:00, 14.55it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.28it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.50it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01, 10.06it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.80it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.64it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.50it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:00<00:00,  9.37it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  9.29it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  9.12it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  9.06it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  9.01it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.97it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.92it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  9.06it/s]
# Epoch 20: 100%|██████████| 62/62 [00:25<00:00,  2.41it/s, v_num=6, train_loss_step=0.0594, val_loss=0.504, train_loss_epoch=0.0271]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 65.93it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:01,  8.56it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01,  8.22it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01,  8.05it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  8.01it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  8.04it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:01,  8.02it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  8.09it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:01<00:00,  8.14it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  8.10it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.07it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.07it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.06it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.04it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.03it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.19it/s]
# Epoch 21: 100%|██████████| 62/62 [00:26<00:00,  2.38it/s, v_num=6, train_loss_step=0.0393, val_loss=0.467, train_loss_epoch=0.0255]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 75.55it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:01, 13.56it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 10.99it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.04it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.55it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.25it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.06it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  8.96it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:01<00:00,  8.86it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  8.78it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.70it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.67it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.66it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.64it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.62it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.75it/s]
# Epoch 22: 100%|██████████| 62/62 [00:26<00:00,  2.34it/s, v_num=6, train_loss_step=0.0274, val_loss=0.708, train_loss_epoch=0.0324]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 75.26it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:00, 14.44it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.33it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.25it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.72it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.40it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.18it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  8.97it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:01<00:00,  8.92it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  8.88it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.83it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.75it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.71it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.69it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.67it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.81it/s]
# Epoch 23: 100%|██████████| 62/62 [00:26<00:00,  2.33it/s, v_num=6, train_loss_step=0.00727, val_loss=0.426, train_loss_epoch=0.0326]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 77.18it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:00, 14.20it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.34it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.42it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.81it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.48it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.34it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.21it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:00<00:00,  9.13it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  9.06it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  9.01it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.99it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.92it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.91it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.85it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.98it/s]
# Epoch 24: 100%|██████████| 62/62 [00:26<00:00,  2.36it/s, v_num=6, train_loss_step=0.00235, val_loss=0.468, train_loss_epoch=0.0322]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 80.96it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:00, 14.17it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.18it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.25it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.80it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.50it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.35it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.26it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:00<00:00,  9.13it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  9.07it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  9.01it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.98it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.93it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.90it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.88it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  9.02it/s]
# Epoch 25: 100%|██████████| 62/62 [00:25<00:00,  2.40it/s, v_num=6, train_loss_step=0.0768, val_loss=0.488, train_loss_epoch=0.0216]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 73.92it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:01, 13.59it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 10.88it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01,  9.92it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.45it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.18it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:01,  8.98it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  8.85it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:01<00:00,  8.73it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  8.64it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.59it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.52it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.49it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.45it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.42it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.56it/s]
# Epoch 26: 100%|██████████| 62/62 [00:26<00:00,  2.34it/s, v_num=6, train_loss_step=0.207, val_loss=0.458, train_loss_epoch=0.0398]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 74.28it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:01, 11.45it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01,  9.78it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01,  9.19it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  8.92it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  8.75it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:01,  8.65it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  8.54it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:01<00:00,  8.46it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  8.41it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.39it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.36it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.34it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.31it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.29it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.44it/s]
# Epoch 27: 100%|██████████| 62/62 [00:26<00:00,  2.35it/s, v_num=6, train_loss_step=0.00377, val_loss=0.439, train_loss_epoch=0.0416]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 66.62it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:01, 13.64it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 10.93it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.02it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.51it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.31it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.17it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.00it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:01<00:00,  8.84it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  8.74it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.64it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.59it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.54it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.51it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.47it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.62it/s]
# Epoch 28: 100%|██████████| 62/62 [00:26<00:00,  2.32it/s, v_num=6, train_loss_step=0.00312, val_loss=0.518, train_loss_epoch=0.0291]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 55.30it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:02,  5.87it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:02,  6.36it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01,  6.65it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  6.87it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  7.03it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:01,  7.16it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:01<00:01,  7.25it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:01<00:00,  7.32it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  7.38it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  7.44it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  7.50it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  7.57it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  7.63it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  7.68it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:02<00:00,  7.84it/s]
# Epoch 29: 100%|██████████| 62/62 [00:26<00:00,  2.36it/s, v_num=6, train_loss_step=0.0111, val_loss=0.576, train_loss_epoch=0.0123]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:00, 79.15it/s]
# Validation DataLoader 0:  12%|█▎        | 2/16 [00:00<00:00, 14.22it/s]
# Validation DataLoader 0:  19%|█▉        | 3/16 [00:00<00:01, 11.33it/s]
# Validation DataLoader 0:  25%|██▌       | 4/16 [00:00<00:01, 10.39it/s]
# Validation DataLoader 0:  31%|███▏      | 5/16 [00:00<00:01,  9.91it/s]
# Validation DataLoader 0:  38%|███▊      | 6/16 [00:00<00:01,  9.62it/s]
# Validation DataLoader 0:  44%|████▍     | 7/16 [00:00<00:00,  9.39it/s]
# Validation DataLoader 0:  50%|█████     | 8/16 [00:00<00:00,  9.24it/s]
# Validation DataLoader 0:  56%|█████▋    | 9/16 [00:00<00:00,  9.09it/s]
# Validation DataLoader 0:  62%|██████▎   | 10/16 [00:01<00:00,  8.95it/s]
# Validation DataLoader 0:  69%|██████▉   | 11/16 [00:01<00:00,  8.86it/s]
# Validation DataLoader 0:  75%|███████▌  | 12/16 [00:01<00:00,  8.80it/s]
# Validation DataLoader 0:  81%|████████▏ | 13/16 [00:01<00:00,  8.78it/s]
# Validation DataLoader 0:  88%|████████▊ | 14/16 [00:01<00:00,  8.74it/s]
# Validation DataLoader 0:  94%|█████████▍| 15/16 [00:01<00:00,  8.72it/s]
# Validation DataLoader 0: 100%|██████████| 16/16 [00:01<00:00,  8.87it/s]
# Epoch 29: 100%|██████████| 62/62 [00:30<00:00,  2.03it/s, v_num=6, train_loss_step=0.0111, val_loss=0.501, train_loss_epoch=0.028]

# %%
# %reload_ext tensorboard
# %tensorboard --logdir /home/kersten/gejji003/Shadows/trained_models/round1/logger/my_experiment/version_5 --port=6006# Specify the directory where your logs are stored
# Out:
# ERROR: Could not find `tensorboard`. Please ensure that your PATH
# contains an executable `tensorboard` program, or explicitly specify
# the path to a TensorBoard binary by setting the `TENSORBOARD_BINARY`
# environment variable.

# %%
# %reload_ext tensorboard

# %% [markdown]
# # Predict and GradCam

# %%
def predict(myModelPath, myBatchSize, myNumWorkers):
    model = MYEfficientNetModel.load_from_checkpoint(myModelPath)
    model.eval()
    model.cuda()

#     df_test = pd.read_csv("/panfs/jay/groups/27/kersten/gejji003/Shadows/data/images_rendered_try2/testData.csv")
# # df=self.dfTest, mount_point=self.mountPoint, label=self.label, img_col=self.img_path, color=self.color, transform=self.valid_transform
#     test_ds = MyDataLoading(df=df_test, img_col="path_to_img", label="label", color="colors", transform=shadowValTransforms)
#     self.test_data = MyDataLoading(self.testX, self.testY, color_channel = self.color_channel, shadow_channel =self.shadow_channel,mode = "train" , transforms =  self.transforms_train )
#     test_loader = DataLoader(test_ds, batch_size=myBatchSize, shuffle=False, num_workers=myNumWorkers, pin_memory=True, prefetch_factor=4)
    test_loader = dataset.test_dataloader()

    y_all = []
    pred_all = []
    with torch.no_grad():
        pbar = tqdm(enumerate(test_loader), total=len(test_loader))
        for idx, X in pbar:
            X, y = X
            X = X.cuda().contiguous()
            # print("TYPE X: ", type(X))
            # y = y.cuda()
            myPred = model(X).squeeze().cuda()
            myPred = myPred.cpu()
            # print(myPred)
            if myPred > 0.08:
                myPred = 1
            else:
                myPred = 0
            # print(type(myPred))
            # y = y.cuda()
            # print(type(y))
            # print(y)
            y_all.append(y.int().numpy())
            # print(myPred)
            pred_all.append(myPred)
            # print(y_all)
            # print(pred_all)
        
        myClassRep = classification_report(y_all, pred_all)
        print(myClassRep)
        myConfMat = confusion_matrix(y_all, pred_all)
        print(myConfMat)

# %%
myModelPath = "/home/kersten/gejji003/Shadows/trained_models/round1/checkpoint/model-epoch=11-val_loss=0.34.ckpt"
myBatchSize = 1
myNumWorkers = 16
predict(myModelPath = myModelPath, myBatchSize = myBatchSize, myNumWorkers = myNumWorkers)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       2 myBatchSize = 1
#       3 myNumWorkers = 16
# ----> 4 predict(myModelPath = myModelPath, myBatchSize = myBatchSize, myNumWorkers = myNumWorkers)
#
# TypeError: predict() missing 1 required positional argument: 'myCSVPath'

# %%
import tqdm
from captum.attr import GuidedGradCam
# import captum.attr
